# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

import time

# %%
BASE_URL = "https://www.basketball-reference.com/"

# %%
# Scrape GSW box score links from a team game page
team_1_url = "https://www.basketball-reference.com/teams/GSW/2022_games.html"


response = requests.get(team_1_url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table')

team_1_boxscore_links = []
for tr in table.findAll("tr"):
    trs = tr.findAll("td")
    for each in trs:
        try:
            link = each.find('a')['href']
            if "teams" in link or "boxscores/index" in link:
                continue    
            team_1_boxscore_links.append(link)
        except:
            pass


# Scrape BOS box score links from a team game page
team_2_url = "https://www.basketball-reference.com/teams/BOS/2022_games.html"


# df = pd.read_html(url)[0]
# df = df.loc[df["Date"] != "Date"].copy()
# df.reset_index(inplace=True, drop=True)

response = requests.get(team_2_url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table')

team_2_boxscore_links = []
for tr in table.findAll("tr"):
    trs = tr.findAll("td")
    for each in trs:
        try:
            link = each.find('a')['href']
            if "teams" in link or "boxscores/index" in link:
                continue    
            team_2_boxscore_links.append(link)
        except:
            pass

# %%
team1_pbp_links = [link.replace("/boxscores", f"{BASE_URL}boxscores/pbp") for link in team_1_boxscore_links]
team2_pbp_links = [link.replace("/boxscores", f"{BASE_URL}boxscores/pbp") for link in team_2_boxscore_links]

# %%
def boxscore_pbp_to_distilgpt2(boxscore_urls, debug=False):
    """Given a list of urls to team boxscores, return training text and validation text"""

    training_text = ""
    validation_text = ""

    for link in boxscore_urls:
        if debug:
            print(link)
        pbp = pd.read_html(link)[0]
        # convert nulls to str represenaion of NaN
        pbp = pbp.astype(str) 
        pbp.columns = pbp.columns.droplevel()
        pbp.columns = ["Time", "Team1", "Team1points", "Score", "Team2points", "Team2"]
        # mid-game jump balls throw off the parser, it's easier to just remove them
        pbp = pbp.loc[(~pbp["Score"].str.startswith("Jump ball")) & (pbp["Time"] != "12:00")]
        pbp.reset_index(inplace=True, drop=True)

        # one game play by play table
        game_text = ""
        quarter = 1
        for i, record in pbp.iterrows():
            # placeholder for integer representation of the quarter
            
            if record["Team1"] != "nan":
                play = record["Team1"]
            elif record["Team2"] != "nan":
                play = record["Team2"] 
            else:
                # this should be end of quarters
                play = record["Score"]
            
            if play.startswith("Start of "):
                quarter+=1
                # don't write this line to the text
                continue

            time_left = record["Time"][:-2]
            score = record["Score"]
            if score.startswith("End of"):
                # get the score from the previous line
                scores = pbp.iloc[i-1]["Score"].split("-")
                team1_score = int(scores[0])
                team2_score = int(scores[1])
                score = f"{team1_score}-{team2_score}"
            
            # check if the game is over
            if quarter >= 4 and time_left == "0:00":
                if team1_score != team2_score:
                    # game is over, add a distilgpt2 endoftext token
                    game_text+=f"{quarter} {time_left} {score} End of Game\n"
                    game_text+="<|endoftext|>"
                    
                    # decide where to put the game, train or val
                    split = np.random.choice(["train", "val"], p=[0.8, 0.2])
                    if split == "train":
                        training_text += game_text + "\n"
                    else:
                        validation_text += game_text + "\n"
                    
                    # reset game_text
                    game_text = ""
                    quarter = 1
            else:
                if score == play or score == "Score":
                    # these are header rows
                    # 4th Q == 4th Q for example
                    continue
                else:
                    game_text += f"{quarter} {time_left} {score} {play}\n"
        # be nice to the API
        time.sleep(0.1)
    return training_text, validation_text

# %%
team1_training_text, team1_validation_text = boxscore_pbp_to_distilgpt2(team1_pbp_links, debug=False)
team2_training_text, team2_validation_text = boxscore_pbp_to_distilgpt2(team2_pbp_links, debug=False)
# Out:
# https://www.basketball-reference.com/boxscores/pbp/202110190LAL.html
# https://www.basketball-reference.com/boxscores/pbp/202110210GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202110240SAC.html
# https://www.basketball-reference.com/boxscores/pbp/202110260OKC.html
# https://www.basketball-reference.com/boxscores/pbp/202110280GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202110300GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111030GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111050GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111070GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111080GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111100GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111120GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111140CHO.html
# https://www.basketball-reference.com/boxscores/pbp/202111160BRK.html
# https://www.basketball-reference.com/boxscores/pbp/202111180CLE.html
# https://www.basketball-reference.com/boxscores/pbp/202111190DET.html
# https://www.basketball-reference.com/boxscores/pbp/202111210GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111240GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111260GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202111280LAC.html
# https://www.basketball-reference.com/boxscores/pbp/202111300PHO.html
# https://www.basketball-reference.com/boxscores/pbp/202112030GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202112040GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202112060GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202112080GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202112110PHI.html
# https://www.basketball-reference.com/boxscores/pbp/202112130IND.html
# https://www.basketball-reference.com/boxscores/pbp/202112140NYK.html
# https://www.basketball-reference.com/boxscores/pbp/202112170BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202112180TOR.html
# https://www.basketball-reference.com/boxscores/pbp/202112200GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202112230GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202112250PHO.html
# https://www.basketball-reference.com/boxscores/pbp/202112280GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201010UTA.html
# https://www.basketball-reference.com/boxscores/pbp/202201030GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201050DAL.html
# https://www.basketball-reference.com/boxscores/pbp/202201060NOP.html
# https://www.basketball-reference.com/boxscores/pbp/202201090GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201110MEM.html
# https://www.basketball-reference.com/boxscores/pbp/202201130MIL.html
# https://www.basketball-reference.com/boxscores/pbp/202201140CHI.html
# https://www.basketball-reference.com/boxscores/pbp/202201160MIN.html
# https://www.basketball-reference.com/boxscores/pbp/202201180GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201200GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201210GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201230GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201250GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201270GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201290GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202201310HOU.html
# https://www.basketball-reference.com/boxscores/pbp/202202010SAS.html
# https://www.basketball-reference.com/boxscores/pbp/202202030GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202202070OKC.html
# https://www.basketball-reference.com/boxscores/pbp/202202090UTA.html
# https://www.basketball-reference.com/boxscores/pbp/202202100GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202202120GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202202140LAC.html
# https://www.basketball-reference.com/boxscores/pbp/202202160GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202202240POR.html
# https://www.basketball-reference.com/boxscores/pbp/202202270GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202203010MIN.html
# https://www.basketball-reference.com/boxscores/pbp/202203030DAL.html
# https://www.basketball-reference.com/boxscores/pbp/202203050LAL.html
# https://www.basketball-reference.com/boxscores/pbp/202203070DEN.html
# https://www.basketball-reference.com/boxscores/pbp/202203080GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202203100DEN.html
# https://www.basketball-reference.com/boxscores/pbp/202203120GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202203140GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202203160GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202203200GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202203220ORL.html
# https://www.basketball-reference.com/boxscores/pbp/202203230MIA.html
# https://www.basketball-reference.com/boxscores/pbp/202203250ATL.html
# https://www.basketball-reference.com/boxscores/pbp/202203270WAS.html
# https://www.basketball-reference.com/boxscores/pbp/202203280MEM.html
# https://www.basketball-reference.com/boxscores/pbp/202203300GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202204020GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202204030SAC.html
# https://www.basketball-reference.com/boxscores/pbp/202204070GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202204090SAS.html
# https://www.basketball-reference.com/boxscores/pbp/202204100NOP.html
# https://www.basketball-reference.com/boxscores/pbp/202110200NYK.html
# https://www.basketball-reference.com/boxscores/pbp/202110220BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202110240HOU.html
# https://www.basketball-reference.com/boxscores/pbp/202110250CHO.html
# https://www.basketball-reference.com/boxscores/pbp/202110270BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202110300WAS.html
# https://www.basketball-reference.com/boxscores/pbp/202111010BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202111030ORL.html
# https://www.basketball-reference.com/boxscores/pbp/202111040MIA.html
# https://www.basketball-reference.com/boxscores/pbp/202111060DAL.html
# https://www.basketball-reference.com/boxscores/pbp/202111100BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202111120BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202111130CLE.html
# https://www.basketball-reference.com/boxscores/pbp/202111150CLE.html
# https://www.basketball-reference.com/boxscores/pbp/202111170ATL.html
# https://www.basketball-reference.com/boxscores/pbp/202111190BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202111200BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202111220BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202111240BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202111260SAS.html
# https://www.basketball-reference.com/boxscores/pbp/202111280TOR.html
# https://www.basketball-reference.com/boxscores/pbp/202112010BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202112030UTA.html
# https://www.basketball-reference.com/boxscores/pbp/202112040POR.html
# https://www.basketball-reference.com/boxscores/pbp/202112070LAL.html
# https://www.basketball-reference.com/boxscores/pbp/202112080LAC.html
# https://www.basketball-reference.com/boxscores/pbp/202112100PHO.html
# https://www.basketball-reference.com/boxscores/pbp/202112130BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202112170BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202112180BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202112200BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202112220BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202112250MIL.html
# https://www.basketball-reference.com/boxscores/pbp/202112270MIN.html
# https://www.basketball-reference.com/boxscores/pbp/202112290BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202112310BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201020BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201050BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201060NYK.html
# https://www.basketball-reference.com/boxscores/pbp/202201080BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201100BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201120IND.html
# https://www.basketball-reference.com/boxscores/pbp/202201140PHI.html
# https://www.basketball-reference.com/boxscores/pbp/202201150BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201170BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201190BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201210BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201230WAS.html
# https://www.basketball-reference.com/boxscores/pbp/202201250BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202201280ATL.html
# https://www.basketball-reference.com/boxscores/pbp/202201290NOP.html
# https://www.basketball-reference.com/boxscores/pbp/202201310BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202202020BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202202040DET.html
# https://www.basketball-reference.com/boxscores/pbp/202202060ORL.html
# https://www.basketball-reference.com/boxscores/pbp/202202080BRK.html
# https://www.basketball-reference.com/boxscores/pbp/202202110BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202202130BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202202150PHI.html
# https://www.basketball-reference.com/boxscores/pbp/202202160BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202202240BRK.html
# https://www.basketball-reference.com/boxscores/pbp/202202260DET.html
# https://www.basketball-reference.com/boxscores/pbp/202202270IND.html
# https://www.basketball-reference.com/boxscores/pbp/202203010BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202203030BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202203060BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202203090CHO.html
# https://www.basketball-reference.com/boxscores/pbp/202203110BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202203130BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202203160GSW.html
# https://www.basketball-reference.com/boxscores/pbp/202203180SAC.html
# https://www.basketball-reference.com/boxscores/pbp/202203200DEN.html
# https://www.basketball-reference.com/boxscores/pbp/202203210OKC.html
# https://www.basketball-reference.com/boxscores/pbp/202203230BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202203270BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202203280TOR.html
# https://www.basketball-reference.com/boxscores/pbp/202203300BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202204010BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202204030BOS.html
# https://www.basketball-reference.com/boxscores/pbp/202204060CHI.html
# https://www.basketball-reference.com/boxscores/pbp/202204070MIL.html
# https://www.basketball-reference.com/boxscores/pbp/202204100MEM.html

# %%
TRAINING_FILENAME = "data/BOS_GSW_pbp_2021-22_for_distilgpt2.train.txt"
VALIDATION_FILENAME = "data/BOS_GSW_pbp_2021-22_for_distilgpt2.validation.txt"

with open (TRAINING_FILENAME, "w") as f:
    f.write(team1_training_text)
    f.write(team2_training_text)

with open(VALIDATION_FILENAME, "w") as f:
    f.write(team1_validation_text)
    f.write(team2_validation_text)
